# %% [markdown]
# <a href="https://colab.research.google.com/github/luiscarlosm33/SIM_YAC_UPSE2023/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tutorial to find fourier transform
from scipy.fft import fft, ifft
import numpy as np
x = np.array([1.0, 2.0, 1.0, -1.0, 1.5])
y = fft(x)
y
# Out:
# array([ 4.5       -0.j        ,  2.08155948-1.65109876j,
#        -1.83155948+1.60822041j, -1.83155948-1.60822041j,
#         2.08155948+1.65109876j])

# %%
yinv = ifft(y)
yinv
# Out:
# array([ 1. +0.j,  2. +0.j,  1. +0.j, -1. +0.j,  1.5+0.j])

# %%
# Tutorial on using Pwelch Fourier transform
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
rng = np.random.default_rng()

# %%
# !pip install -q ipympl

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(3*x)
plt.figure()
ax.plot(x, y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fs = 10e3
N = 1e5
amp = 2*np.sqrt(2)
freq = 1234.0
noise_power = 0.001 * fs / 2
time = np.arange(N) / fs
x = amp*np.sin(2*np.pi*freq*time)
x += rng.normal(scale=np.sqrt(noise_power), size=time.shape)

# %%
f, Pxx_den = signal.welch(x, fs, nperseg=1024)
plt.figure()
plt.semilogy(f, Pxx_den)
plt.ylim([0.5e-3, 1])
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
max(Pxx_den)
# Out:
# 0.23076216896356794

# %%
index = np.where(Pxx_den == max(Pxx_den))[0]

# %%
index
# Out:
# array([126])

# %%
# Out:
# 513

# %%
# Calculo de Numero de membranas
# Obteniendo eficiencias para dos casos
